# %%
#import libraries
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# /var/folders/vb/_p4jxwn10w93p4lw51cwhhb80000gn/T/ipykernel_80417/2350612576.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %%
#read the first few rows
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
df.shape   #over 7 million entries, 13 columns
# Out:
# (7461195, 13)

# %%
#types for each column
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#only want races which are 50km and 50miles in 2020
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
#All events in USA
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#combine the filters
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA') ]
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df2 = df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA') ]
df2.head(10)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# 2539950           2020  02.02.2020
# 2539951           2020  02.02.2020
# 2539952           2020  02.02.2020
# 2539953           2020  02.02.2020
# 2539954           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539950  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
#add age (as of race date)
df2['athlete_age'] = 2020 - df2['Athlete year of birth']
# Out:
# /var/folders/vb/_p4jxwn10w93p4lw51cwhhb80000gn/T/ipykernel_80417/3168796883.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['athlete_age'] = 2020 - df2['Athlete year of birth']

# %%
#remove h from athlete performance
df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# /var/folders/vb/_p4jxwn10w93p4lw51cwhhb80000gn/T/ipykernel_80417/2008538698.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)

# %%
#drop columns: Athlete Club, Athlete Country, Athlete year of birth, Athlete Age Category
df2 = df2.drop(['Athlete club', 'Athlete country', 'Athlete year of birth', 'Athlete age category'], axis = 1)

# %%
df2.head(2)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance Athlete gender  \
# 2539945                         20             3:17:55              M
# 2539946                         20             4:02:32              M
#
#         Athlete average speed  Athlete ID  athlete_age
# 2539945                15.158       71287         29.0
# 2539946                12.369      629508         39.0

# %%
#null values for age
df2[df2['athlete_age'].isna() == 1]
# Out:
#          Year of event Event dates                                Event name  \
# 2547794           2020  25.01.2020        North Carolina Fat Ass 50 Km (USA)
# 2551331           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K (USA)
# 2551336           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K (USA)
# 2551344           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K (USA)
# 2551348           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K (USA)
# ...                ...         ...                                       ...
# 2746543           2020  17.10.2020     Black River Trail Classic 50 Km (USA)
# 2749869           2020  17.10.2020  MuleSkinner Endurance 50 Mile Race (USA)
# 2755985           2020  10.10.2020      Man Against Horse 50 Mile Race (USA)
# 2755994           2020  10.10.2020      Man Against Horse 50 Mile Race (USA)
# 2755997           2020  10.10.2020      Man Against Horse 50 Mile Race (USA)
#
# ...

# %%
df2 = df2.dropna()

# %%
#check fo duplicates
df2[df2.duplicated()== True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
#reset index
df2.reset_index(drop = True)
# Out:
#        Year of event Event dates  \
# 0               2020  02.02.2020
# 1               2020  02.02.2020
# 2               2020  02.02.2020
# 3               2020  02.02.2020
# 4               2020  02.02.2020
# ...              ...         ...
# 25852           2020  03.10.2020
# 25853           2020  03.10.2020
# 25854           2020  03.10.2020
# 25855           2020  03.10.2020
# 25856           2020  03.10.2020
#
#                                           Event name Event distance/length  \
# 0      West Seattle Beach Run - Winter Edition (USA)                  50km
# 1      West Seattle Beach Run - Winter Edition (USA)                  50km
# 2      West Seattle Beach Run - Winter Edition (USA)                  50km
# 3      West Seattle Beach Run - Winter Edition (USA)                  50km
# 4      West Seattle Beach Run - Winter Edition (USA)                  50km
# ...                                              ...                   ...
# ...

# %%
#fix types
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# athlete_age                  float64
# dtype: object

# %%
df2['athlete_age'] = df2['athlete_age'].astype(int)

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int64
# dtype: object

# %%
#rename columns
df2 = df2.rename(columns = {'Year of event': 'year',
                            'Event dates':'race_day',
                            'Event name':'race_name',
                            'Event distance/length':'race_length',
                            'Event number of finishers': 'race_number_of_finishers',
                            'Athlete performance':'athlete_performance',
                            'Athlete gender': 'athlete_gender',
                            'Athlete average speed': 'athlete_average_speed',
                            'Athlete ID': 'athlete_id'
                            })

# %%
df2.drop(['year'],axis =1)
# Out:
#            race_day                                      race_name  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# ...             ...                                            ...
# 2760957  03.10.2020   Yankee Springs Fall Trail Run Festival (USA)
# 2760958  03.10.2020   Yankee Springs Fall Trail Run Festival (USA)
# 2760959  03.10.2020   Yankee Springs Fall Trail Run Festival (USA)
# 2760960  03.10.2020   Yankee Springs Fall Trail Run Festival (USA)
# 2760961  03.10.2020   Yankee Springs Fall Trail Run Festival (USA)
#
#         race_length  race_number_of_finishers athlete_performance  \
# 2539945        50km                        20             3:17:55
# ...

# %%
df3 = df2[['race_day','race_name','race_length','race_number_of_finishers','athlete_id','athlete_gender','athlete_age','athlete_performance','athlete_average_speed']]

# %%
df3.head()
# Out:
#            race_day                                      race_name  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
#
#         race_length  race_number_of_finishers  athlete_id athlete_gender  \
# 2539945        50km                        20       71287              M
# 2539946        50km                        20      629508              M
# 2539947        50km                        20       64838              M
# 2539948        50km                        20      704450              M
# 2539949        50km                        20      810281              M
#
#          athlete_age athlete_performance  athlete_average_speed
# ...

# %%
#find race
df3[df3['race_name'] == 'West Seattle Beach Run - Winter Edition (USA)']
# Out:
#            race_day                                      race_name  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539950  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539951  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539952  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539953  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539954  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539955  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539956  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# 2539957  02.02.2020  West Seattle Beach Run - Winter Edition (USA)
# ...

# %% [markdown]
# Charts and graphs

# %%
#distribution of athlete average speed for 50 mile races
sns.displot(df3[df3['race_length'] == '50mi']['athlete_average_speed'])

# %%
sns.histplot(df3,x = 'race_length', hue = 'athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %% [markdown]
# For 50 miile races, majority of athletes are men, where for 50km races, there is more of a 50/50 split between men and women

# %%
#compare male and female
sns.violinplot(data = df3, x = 'race_length', y = 'athlete_average_speed', hue = 'athlete_gender', split = True, inner = 'quartz', linewidth= 1 )
# Out:
# <Axes: xlabel='race_length', ylabel='athlete_average_speed'>

# %% [markdown]
# Answering certain questions from the Dataset

# %%
#which 15 age groups are the fastest in the 50m Race(people with at least 20 races)
df3.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = False).query('count>19').head(15)
# Out:
#                  mean  count
# athlete_age
# 29           7.902252    135
# 23           7.779800     55
# 28           7.575252    107
# 30           7.569204    157
# 25           7.540923     91
# 31           7.451638    138
# 38           7.430022    231
# 35           7.422359    195
# 36           7.403854    185
# 26           7.379800     75
# 33           7.379188    149
# 22           7.367902     41
# 24           7.354274     73
# 42           7.327656    209
# 34           7.319011    182

# %%
#which 15 age groups are the slowest in the 50m Race(people with at least 20 races)
df3.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = True).query('count>19').head(15)
# Out:
#                  mean  count
# athlete_age
# 60           6.261788     33
# 62           6.272730     37
# 61           6.358355     31
# 63           6.514806     31
# 58           6.582328     67
# 64           6.620727     22
# 50           6.671541    172
# 59           6.672072     83
# 48           6.696853    136
# 56           6.708373     67
# 53           6.736969     96
# 57           6.783205     78
# 49           6.789553    159
# 54           6.805506     83
# 55           6.828623     69
